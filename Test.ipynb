# %%
import pandas as pd

url = 'https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'

# %%
fuel_data=pd.read_csv(url,error_bad_lines=False)
fuel_data.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2006_12_195_5_8               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
fuel_data.head(5)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fuel_data.groupby(['fuel_type_code_pudl']).mean()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                       115.637534  2004.623143     1.903473e+06
# gas                        124.122062  2005.978060     4.843183e+06
# nuclear                    107.397311  2002.970660     5.454838e+06
# oil                        113.236235  2007.195933     6.311677e+04
# other                      110.467066  2001.700599     2.948137e+06
# waste                      154.253968  2005.650794     1.171914e+05
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                           20.762780                  67.421830
# gas                             1.021913                  13.659397
# nuclear                        17.582120                4955.157002
# oil                             5.814377                 168.877086
# other                           0.572752                  18.253856
# ...

# %%
fuel_data.groupby(['fuel_mmbtu_per_unit']).describe()
# Out:
#                     utility_id_ferc1                                       \
#                                count        mean        std    min    25%
# fuel_mmbtu_per_unit
# 0.000001                        20.0   86.600000  23.392306   79.0   79.0
# 0.000005                         3.0  112.000000  70.192592   39.0   78.5
# 0.000006                        58.0  122.258621  66.915910   38.0   39.0
# 0.000007                        18.0  125.444444  62.881048   39.0   54.0
# 0.000009                         6.0  193.000000   0.000000  193.0  193.0
# ...                              ...         ...        ...    ...    ...
# 124.855946                       1.0   76.000000        NaN   76.0   76.0
# 124.860000                       1.0   32.000000        NaN   32.0   32.0
# 124.879004                       1.0   46.000000        NaN   46.0   46.0
# 125.120000                       1.0   32.000000        NaN   32.0   32.0
# ...

# %%
print(fuel_data.groupby(["fuel_qty_burned"]).skew())
# Out:
# fuel_qty_burned
# 1.0              utility_id_ferc1               -0.139365
#                  report_year                     0.260194
#                  fuel_mmbtu_per_unit            -2.752201
#                  fuel_cost_per_unit_burned       2.698443
#                  fuel_cost_per_unit_delivered    3.076746
#                                                    ...
# 555894250.0      report_year                          NaN
#                  fuel_mmbtu_per_unit                  NaN
#                  fuel_cost_per_unit_burned            NaN
#                  fuel_cost_per_unit_delivered         NaN
#                  fuel_cost_per_mmbtu                  NaN
# Length: 158754, dtype: float64

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
count_row = fuel_data.shape[0]
count_row
# Out:
# 29523

# %%
fuel_data.groupby('report_year')['fuel_cost_per_unit_burned'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: fuel_cost_per_unit_burned, dtype: int64

# %%
fuel_data.groupby('fuel_cost_per_unit_burned').corr()
# Out:
#                                                         utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.08                   utility_id_ferc1                           NaN
#                           report_year                                NaN
#                           fuel_qty_burned                            NaN
#                           fuel_mmbtu_per_unit                        NaN
#                           fuel_cost_per_unit_delivered               NaN
# ...                                                                  ...
#  139358.00                report_year                                NaN
#                           fuel_qty_burned                            NaN
#                           fuel_mmbtu_per_unit                        NaN
#                           fuel_cost_per_unit_delivered               NaN
#                           fuel_cost_per_mmbtu                        NaN
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-f6b153608749> in <module>
# ----> 1 fuel_data.groupby('fuel_type').count()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 'fuel_qty_burned'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-148c0b336ec8> in <module>
# ----> 1 fuel_data.skew(axis="fuel_qty_burned",skipna=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in skew(self, axis, skipna, level, numeric_only, **kwargs)
#   11133         )
#   11134         def skew(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11135             return NDFrame.skew(self, axis, skipna, level, numeric_only, **kwargs)
#   11136
# ...
